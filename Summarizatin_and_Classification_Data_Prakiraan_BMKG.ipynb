# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilungs/Weather-AI-Analytics/blob/main/Summarizatin_and_Classification_Data_Prakiraan_BMKG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install replicate
# !pip install requests xmltodict
# !git lfs install
# !git clone https://github.com/Bilungs/Weather-AI-Analytics
# Out:
# Requirement already satisfied: replicate in /usr/local/lib/python3.12/dist-packages (1.0.7)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from replicate) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from replicate) (25.0)
# Requirement already satisfied: pydantic>1.10.7 in /usr/local/lib/python3.12/dist-packages (from replicate) (2.11.7)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from replicate) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (4.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.21.0->replicate) (1.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.5)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.12/dist-packages (1.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Git LFS initialized.
# fatal: destination path 'Weather-AI-Analytics' already exists and is not an empty directory.

# %%
from google.colab import userdata, auth
import os, requests, re, json, datetime
import matplotlib.pyplot as plt
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from langchain_community.llms import Replicate
from IPython.display import display, Markdown
from google.auth import default
from collections import defaultdict

# === Konfigurasi Replicate API Token ===
api_token = userdata.get("api_token")

os.environ["REPLICATE_API_TOKEN"] = api_token

# === Pilih wilayah menggunakan API wilayah.id ===
province_code = "32"  # Jawa Barat
city_name_input = "Karawang"
url_city = f"https://wilayah.id/api/regencies/{province_code}.json"
resp_city = requests.get(url_city)

cities = resp_city.json().get("data", [])
kode_wilayah = next((c["code"] for c in cities if city_name_input.lower() in c["name"].lower()), None)

if not kode_wilayah:
    raise ValueError(f"Kota '{city_name_input}' tidak ditemukan di API wilayah.id.")

print("🌍===================================================")
print(f"📍 Prakiraan Cuaca Wilayah: {city_name_input} (Kode: {kode_wilayah})")
print("===================================================\n")

# === Ambil data BMKG ===
url_bmkg = f"https://api.bmkg.go.id/publik/prakiraan-cuaca?adm4={kode_wilayah}"
response = requests.get(url_bmkg, headers={"User-Agent": "Mozilla/5.0"})
data_text = response.text.strip()

today = datetime.date.today()

def build_dummy():
    """Dummy cuaca otomatis sesuai 3 hari ke depan"""
    dummy = []
    for d in range(3):
        base_date = (today + datetime.timedelta(days=d)).strftime("%Y-%m-%d")
        dummy += [
            {"local_datetime":f"{base_date} 00:00:00","t":"24","hu":"85","ws":10,"wd":"Timur","weather_desc":"Berawan","tcc":70},
            {"local_datetime":f"{base_date} 06:00:00","t":"26","hu":"80","ws":14,"wd":"Tenggara","weather_desc":"Cerah","tcc":20},
            {"local_datetime":f"{base_date} 12:00:00","t":"30","hu":"65","ws":22,"wd":"Barat Daya","weather_desc":"Hujan","tcc":100},
            {"local_datetime":f"{base_date} 18:00:00","t":"27","hu":"75","ws":15,"wd":"Barat Laut","weather_desc":"Berawan","tcc":60},
        ]
    return {"data":[{"cuaca": dummy}]}

if data_text.startswith("<!doctype html>") or "Akses diblokir" in data_text:
    print("⚠️ BMKG API diblokir. Menggunakan dummy data simulasi.\n")
    cuaca_data = build_dummy()
else:
    try:
        cuaca_data = response.json()
        if not cuaca_data.get("data"):  # jika kosong fallback ke dummy
            cuaca_data = build_dummy()
    except Exception:
        json_match = re.search(r"\{.*\}", data_text, re.DOTALL)
        cuaca_data = json.loads(json_match.group()) if json_match else build_dummy()

# === Flatten data ===
prakiraan_all = []
cuaca_list = cuaca_data.get("data", [])
if cuaca_list:
    for item in cuaca_list[0].get("cuaca", []):
        prakiraan_all.append(item if isinstance(item, dict) else item[0])

# === Ambil 3 hari ke depan ===
unique_dates = sorted({d["local_datetime"][:10] for d in prakiraan_all})
next_3days = [d for d in unique_dates if datetime.datetime.strptime(d, "%Y-%m-%d").date() >= today][:3]
filtered = [d for d in prakiraan_all if d["local_datetime"][:10] in next_3days]

# ✅ Kelompokkan data per tanggal
grouped = defaultdict(list)
for item in filtered:
    tanggal = item["local_datetime"][:10]
    grouped[tanggal].append(item)

days = [grouped[t] for t in sorted(grouped.keys())[:3]]

if not days:  # fallback terakhir
    days = [build_dummy()["data"][0]["cuaca"][i:i+4] for i in range(0, 12, 4)]

# === Fungsi format tanggal ===
def format_tanggal(tanggal_str):
    dt = datetime.datetime.strptime(tanggal_str, "%Y-%m-%d %H:%M:%S")
    hari_indo = {
        "Monday": "Senin","Tuesday": "Selasa","Wednesday": "Rabu",
        "Thursday": "Kamis","Friday": "Jumat","Saturday": "Sabtu","Sunday": "Minggu"
    }[dt.strftime("%A")]
    return f"{hari_indo}, {dt.strftime('%d %B %Y %H:%M')}"

# === Klasifikasi ===
def classify_day(day):
    weather_list = [d["weather_desc"] for d in day]
    max_wind = max(d["ws"] for d in day)
    rain_count = sum("Hujan" in w for w in weather_list)
    if rain_count > 2: kategori = "Hujan"
    elif weather_list.count("Cerah") > 2 or weather_list.count("Cerah Berawan") > 2: kategori = "Cerah"
    else: kategori = "Berawan"
    ekstrem = []
    if max_wind > 20: ekstrem.append(f"🌬️ Angin kencang {max_wind} km/jam")
    if rain_count/len(day) > 0.5: ekstrem.append("☔ Hujan dominan")
    return kategori, ekstrem

# === Setup Granite ===
llm = Replicate(
    model="ibm-granite/granite-3.3-8b-instruct",
    model_kwargs={"temperature":0.3, "max_tokens":500}
)

# === Loop per Hari ===
all_summary, all_days_df = "", []

for idx, day in enumerate(days, start=1):
    display(Markdown(f"## 📅 Hari ke-{idx} ({day[0]['local_datetime'][:10]})"))
    display(Markdown("---"))

    records, text_data = [], ""
    for item in day:
        records.append({
            "Hari": idx,
            "Waktu": format_tanggal(item["local_datetime"]),
            "🌡️ Suhu (°C)": int(item["t"]),
            "💧 Kelembapan (%)": int(item["hu"]),
            "🌬️ Angin (km/jam)": int(item["ws"]),
            "☁️ Cuaca": item["weather_desc"],
            "Awan (%)": int(item["tcc"])
        })
        text_data += f"- {format_tanggal(item['local_datetime'])} | 🌡️ {item['t']}°C | 💧 {item['hu']}% | {item['weather_desc']} | 🌬️ {item['ws']} km/jam ({item['wd']}) | ☁️ {item['tcc']}%\n"

    df = pd.DataFrame(records)
    all_days_df.append((f"Hari-{idx}", df))

    # 🎨 Tabel styled
    styled_df = (
        df.style.set_caption(f"Tabel Cuaca Hari ke-{idx}")
        .format({
            "🌡️ Suhu (°C)": "{:.0f}",
            "💧 Kelembapan (%)": "{:.0f}",
            "🌬️ Angin (km/jam)": "{:.0f}",
            "Awan (%)": "{:.0f}"
        })
        .background_gradient(subset=["🌡️ Suhu (°C)"], cmap="Oranges")
        .background_gradient(subset=["💧 Kelembapan (%)"], cmap="Blues")
        .background_gradient(subset=["🌬️ Angin (km/jam)"], cmap="Greens")
    )
    display(styled_df)

    # 📈 Grafik tren (hanya 1 chart per hari)
    plt.figure(figsize=(10,5))
    plt.plot(df["Waktu"], df["🌡️ Suhu (°C)"], marker="o", color="orange", label="Suhu (°C)")
    plt.plot(df["Waktu"], df["💧 Kelembapan (%)"], marker="s", color="blue", label="Kelembapan (%)")
    plt.plot(df["Waktu"], df["🌬️ Angin (km/jam)"], marker="^", color="green", label="Angin (km/jam)")
    plt.title(f"Tren Cuaca Hari ke-{idx}")
    plt.xticks(rotation=30)
    plt.xlabel("Waktu")
    plt.ylabel("Nilai")
    plt.legend()
    plt.grid(True)
    plt.show()

    # 📝 Ringkasan AI
    kategori, ekstrem = classify_day(day)
    accuracy = 90 if kategori=="Cerah" else 80 if kategori=="Berawan" else 70
    ekstrem_text = ", ".join(ekstrem) if ekstrem else "Normal ✅"

    prompt = f"""
Ringkas prakiraan cuaca BMKG untuk wilayah {city_name_input} hari ke-{idx}.
Gunakan bahasa santai dengan emoji agar menarik dibaca.
Sertakan kategori cuaca: {kategori}, indikator ekstrem: {ekstrem_text}, perkiraan akurasi: {accuracy}%.
Data:
{text_data}
"""
    summary = llm.invoke(prompt)

    display(Markdown(f"""
### 📝 Ringkasan AI (Hari {idx})
- **Kategori:** {kategori}
- **Ekstrem:** {ekstrem_text}
- **Akurasi:** {accuracy}%

{summary}
    """))

    all_summary += f"Hari {idx}: {summary}\n"

# === Export ke Google Spreadsheet (Per Hari) ===
if all_days_df:
    auth.authenticate_user()
    creds, _ = default()
    gc = gspread.authorize(creds)

    try:
        sh = gc.open("Prakiraan Cuaca 3 Hari")
    except gspread.SpreadsheetNotFound:
        sh = gc.create("Prakiraan Cuaca 3 Hari")

    for sheet_title, df_day in all_days_df:
        try:
            ws_day = sh.worksheet(sheet_title)
        except:
            ws_day = sh.add_worksheet(title=sheet_title, rows=100, cols=20)
        ws_day.clear()
        set_with_dataframe(ws_day, df_day)

    try:
        ws_summary = sh.worksheet("Ringkasan AI")
    except:
        ws_summary = sh.add_worksheet(title="Ringkasan AI", rows=100, cols=10)

    ws_summary.clear()
    ws_summary.update(values=[["Hari", "Ringkasan"]], range_name="A1")
    summary_rows = [line for line in all_summary.split("\n") if line.strip()]
    ws_summary.update(
        values=[[f"Hari {i+1}", s] for i, s in enumerate(summary_rows)],
        range_name="A2"
    )

    print(f"✅ Semua data sudah masuk ke Google Spreadsheet: {sh.url}")

# === Kesimpulan umum
display(Markdown("## 🌈 Kesimpulan Umum 3 Hari ke Depan"))
display(Markdown("---"))

final_prompt = f"""
Berdasarkan prakiraan cuaca BMKG 3 hari ke depan untuk {city_name_input}:

{all_summary}

Buat kesimpulan umum dengan gaya bahasa ramah + emoji.
Berikan juga saran singkat.
"""
final_output = llm.invoke(final_prompt)
display(Markdown(f"### 🌟 Ringkasan Umum\n\n{final_output}"))
# Out:
# 🌍===================================================
# 📍 Prakiraan Cuaca Wilayah: Karawang (Kode: 32.15)
# ===================================================
#
# ⚠️ BMKG API diblokir. Menggunakan dummy data simulasi.
# ## 📅 Hari ke-1 (2025-09-21)
# ---
# <style type="text/css">
# #T_8c14e_row0_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_8c14e_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8c14e_row0_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_8c14e_row1_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_8c14e_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_8c14e_row1_col4 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_8c14e_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_8c14e_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8c14e_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8c14e_row3_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_8c14e_row3_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_8c14e_row3_col4 {
#   background-color: #92d28f;
#   color: #000000;
# }
# </style>
# <table id="T_8c14e" class="dataframe">
#   <caption>Tabel Cuaca Hari ke-1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c14e_level0_col0" class="col_heading level0 col0" >Hari</th>
#       <th id="T_8c14e_level0_col1" class="col_heading level0 col1" >Waktu</th>
#       <th id="T_8c14e_level0_col2" class="col_heading level0 col2" >🌡️ Suhu (°C)</th>
#       <th id="T_8c14e_level0_col3" class="col_heading level0 col3" >💧 Kelembapan (%)</th>
#       <th id="T_8c14e_level0_col4" class="col_heading level0 col4" >🌬️ Angin (km/jam)</th>
#       <th id="T_8c14e_level0_col5" class="col_heading level0 col5" >☁️ Cuaca</th>
#       <th id="T_8c14e_level0_col6" class="col_heading level0 col6" >Awan (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c14e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c14e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8c14e_row0_col1" class="data row0 col1" >Minggu, 21 September 2025 00:00</td>
#       <td id="T_8c14e_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_8c14e_row0_col3" class="data row0 col3" >85</td>
#       <td id="T_8c14e_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_8c14e_row0_col5" class="data row0 col5" >Berawan</td>
#       <td id="T_8c14e_row0_col6" class="data row0 col6" >70</td>
#     </tr>
#     <tr>
#       <th id="T_8c14e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c14e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8c14e_row1_col1" class="data row1 col1" >Minggu, 21 September 2025 06:00</td>
#       <td id="T_8c14e_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_8c14e_row1_col3" class="data row1 col3" >80</td>
#       <td id="T_8c14e_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_8c14e_row1_col5" class="data row1 col5" >Cerah</td>
#       <td id="T_8c14e_row1_col6" class="data row1 col6" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8c14e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c14e_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_8c14e_row2_col1" class="data row2 col1" >Minggu, 21 September 2025 12:00</td>
#       <td id="T_8c14e_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_8c14e_row2_col3" class="data row2 col3" >65</td>
#       <td id="T_8c14e_row2_col4" class="data row2 col4" >22</td>
#       <td id="T_8c14e_row2_col5" class="data row2 col5" >Hujan</td>
#       <td id="T_8c14e_row2_col6" class="data row2 col6" >100</td>
#     </tr>
#     <tr>
#       <th id="T_8c14e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c14e_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_8c14e_row3_col1" class="data row3 col1" >Minggu, 21 September 2025 18:00</td>
#       <td id="T_8c14e_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_8c14e_row3_col3" class="data row3 col3" >75</td>
#       <td id="T_8c14e_row3_col4" class="data row3 col4" >15</td>
#       <td id="T_8c14e_row3_col5" class="data row3 col5" >Berawan</td>
#       <td id="T_8c14e_row3_col6" class="data row3 col6" >60</td>
#     </tr>
#   </tbody>
# </table>
# ### 📝 Ringkasan AI (Hari 1)
# - **Kategori:** Berawan
# - **Ekstrem:** 🌬️ Angin kencang 22 km/jam
# - **Akurasi:** 80%
#
# 🌞 Halo! Berikan prakiraan cuaca BMKG untuk Karawang hari Senin, 21 September 2025. 🌞
#
# Pagi (06:00):
# - Suhu: 26°C
# - Kelembaban udara: 80%
# - Cuaca: Cerah
# - Angin: 14 km/jam (Tenggara)
# - Kemungkinan hujan: 20% 🌫️
#
# Siang (12:00):
# - Suhu: 30°C
# - Kelembaban udara: 65%
# - Cuaca: Hujan
# - Angin: 22 km/jam (Barat Daya)
# - Kemungkinan hujan: 100% 🌧️
#
# Malam (18:00):
# - Suhu: 27°C
# - Kelembaban udara: 75%
# - Cuaca: Berawan
# - Angin: 15 km/jam (Barat Laut)
# - Kemungkinan hujan: 60% 🌬️🌂
#
# Catatan:
# - Ini prakiraan, bukan jaminan cuaca akurat.
# - Ini berasal dari data cuaca sejarah dan prakiraan berdasarkan model cuaca.
#
# Selamat menikmati hari Senin di Karawang! 🌳🌞☔️
# ## 📅 Hari ke-2 (2025-09-22)
# ---
# <style type="text/css">
# #T_75bfb_row0_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_75bfb_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_75bfb_row0_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_75bfb_row1_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_75bfb_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_75bfb_row1_col4 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_75bfb_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_75bfb_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_75bfb_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_75bfb_row3_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_75bfb_row3_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_75bfb_row3_col4 {
#   background-color: #92d28f;
#   color: #000000;
# }
# </style>
# <table id="T_75bfb" class="dataframe">
#   <caption>Tabel Cuaca Hari ke-2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75bfb_level0_col0" class="col_heading level0 col0" >Hari</th>
#       <th id="T_75bfb_level0_col1" class="col_heading level0 col1" >Waktu</th>
#       <th id="T_75bfb_level0_col2" class="col_heading level0 col2" >🌡️ Suhu (°C)</th>
#       <th id="T_75bfb_level0_col3" class="col_heading level0 col3" >💧 Kelembapan (%)</th>
#       <th id="T_75bfb_level0_col4" class="col_heading level0 col4" >🌬️ Angin (km/jam)</th>
#       <th id="T_75bfb_level0_col5" class="col_heading level0 col5" >☁️ Cuaca</th>
#       <th id="T_75bfb_level0_col6" class="col_heading level0 col6" >Awan (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75bfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75bfb_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_75bfb_row0_col1" class="data row0 col1" >Senin, 22 September 2025 00:00</td>
#       <td id="T_75bfb_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_75bfb_row0_col3" class="data row0 col3" >85</td>
#       <td id="T_75bfb_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_75bfb_row0_col5" class="data row0 col5" >Berawan</td>
#       <td id="T_75bfb_row0_col6" class="data row0 col6" >70</td>
#     </tr>
#     <tr>
#       <th id="T_75bfb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75bfb_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_75bfb_row1_col1" class="data row1 col1" >Senin, 22 September 2025 06:00</td>
#       <td id="T_75bfb_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_75bfb_row1_col3" class="data row1 col3" >80</td>
#       <td id="T_75bfb_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_75bfb_row1_col5" class="data row1 col5" >Cerah</td>
#       <td id="T_75bfb_row1_col6" class="data row1 col6" >20</td>
#     </tr>
#     <tr>
#       <th id="T_75bfb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75bfb_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_75bfb_row2_col1" class="data row2 col1" >Senin, 22 September 2025 12:00</td>
#       <td id="T_75bfb_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_75bfb_row2_col3" class="data row2 col3" >65</td>
#       <td id="T_75bfb_row2_col4" class="data row2 col4" >22</td>
#       <td id="T_75bfb_row2_col5" class="data row2 col5" >Hujan</td>
#       <td id="T_75bfb_row2_col6" class="data row2 col6" >100</td>
#     </tr>
#     <tr>
#       <th id="T_75bfb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75bfb_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_75bfb_row3_col1" class="data row3 col1" >Senin, 22 September 2025 18:00</td>
#       <td id="T_75bfb_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_75bfb_row3_col3" class="data row3 col3" >75</td>
#       <td id="T_75bfb_row3_col4" class="data row3 col4" >15</td>
#       <td id="T_75bfb_row3_col5" class="data row3 col5" >Berawan</td>
#       <td id="T_75bfb_row3_col6" class="data row3 col6" >60</td>
#     </tr>
#   </tbody>
# </table>
# ### 📝 Ringkasan AI (Hari 2)
# - **Kategori:** Berawan
# - **Ekstrem:** 🌬️ Angin kencang 22 km/jam
# - **Akurasi:** 80%
#
# 🌞 Hai Karawang! Hari ke-2, 23 September 2025, BMKG prakirakan cuaca yang lebih cerah dibandingkan hari sebelumnya. Siang hari, suhu mencapai 28°C, kelembaban udara 70%, dan ada kemungkinan hujan sekitar 30%. Angin bergema dari arah Barat Laut dengan kelanjutan 22 km/jam. 🌬️ Ini termasuk kategori Berawan dengan indikator ekstrem angin sekitar 22 km/jam, perkiraan akurasi 80%. Tetap siap untuk cuaca yang bisa berubah, jadi jangan lupa saja kak! ☂️🌤️
#
# Catatan: Data cuaca tersebut adalah prediksi dan dapat berubah. Sempat diingatkan ya! 😊🌦️
# ## 📅 Hari ke-3 (2025-09-23)
# ---
# <style type="text/css">
# #T_75ff2_row0_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_75ff2_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_75ff2_row0_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_75ff2_row1_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_75ff2_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_75ff2_row1_col4 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_75ff2_row2_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_75ff2_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_75ff2_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_75ff2_row3_col2 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_75ff2_row3_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_75ff2_row3_col4 {
#   background-color: #92d28f;
#   color: #000000;
# }
# </style>
# <table id="T_75ff2" class="dataframe">
#   <caption>Tabel Cuaca Hari ke-3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75ff2_level0_col0" class="col_heading level0 col0" >Hari</th>
#       <th id="T_75ff2_level0_col1" class="col_heading level0 col1" >Waktu</th>
#       <th id="T_75ff2_level0_col2" class="col_heading level0 col2" >🌡️ Suhu (°C)</th>
#       <th id="T_75ff2_level0_col3" class="col_heading level0 col3" >💧 Kelembapan (%)</th>
#       <th id="T_75ff2_level0_col4" class="col_heading level0 col4" >🌬️ Angin (km/jam)</th>
#       <th id="T_75ff2_level0_col5" class="col_heading level0 col5" >☁️ Cuaca</th>
#       <th id="T_75ff2_level0_col6" class="col_heading level0 col6" >Awan (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75ff2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75ff2_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_75ff2_row0_col1" class="data row0 col1" >Selasa, 23 September 2025 00:00</td>
#       <td id="T_75ff2_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_75ff2_row0_col3" class="data row0 col3" >85</td>
#       <td id="T_75ff2_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_75ff2_row0_col5" class="data row0 col5" >Berawan</td>
#       <td id="T_75ff2_row0_col6" class="data row0 col6" >70</td>
#     </tr>
#     <tr>
#       <th id="T_75ff2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75ff2_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_75ff2_row1_col1" class="data row1 col1" >Selasa, 23 September 2025 06:00</td>
#       <td id="T_75ff2_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_75ff2_row1_col3" class="data row1 col3" >80</td>
#       <td id="T_75ff2_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_75ff2_row1_col5" class="data row1 col5" >Cerah</td>
#       <td id="T_75ff2_row1_col6" class="data row1 col6" >20</td>
#     </tr>
#     <tr>
#       <th id="T_75ff2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75ff2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_75ff2_row2_col1" class="data row2 col1" >Selasa, 23 September 2025 12:00</td>
#       <td id="T_75ff2_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_75ff2_row2_col3" class="data row2 col3" >65</td>
#       <td id="T_75ff2_row2_col4" class="data row2 col4" >22</td>
#       <td id="T_75ff2_row2_col5" class="data row2 col5" >Hujan</td>
#       <td id="T_75ff2_row2_col6" class="data row2 col6" >100</td>
#     </tr>
#     <tr>
#       <th id="T_75ff2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75ff2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_75ff2_row3_col1" class="data row3 col1" >Selasa, 23 September 2025 18:00</td>
#       <td id="T_75ff2_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_75ff2_row3_col3" class="data row3 col3" >75</td>
#       <td id="T_75ff2_row3_col4" class="data row3 col4" >15</td>
#       <td id="T_75ff2_row3_col5" class="data row3 col5" >Berawan</td>
#       <td id="T_75ff2_row3_col6" class="data row3 col6" >60</td>
#     </tr>
#   </tbody>
# </table>
# ### 📝 Ringkasan AI (Hari 3)
# - **Kategori:** Berawan
# - **Ekstrem:** 🌬️ Angin kencang 22 km/jam
# - **Akurasi:** 80%
#
# 🌞 Hai karawangi, hari ke-3 (23 September 2025) bakal membawa cuaca yang bervariasi! 🌞
#
# Pagi hari, sekitar 06:00 WIB, cuaca di Karawang cerah dengan suhu 26°C dan keseimbangan angin yang lebih cepat di selatan sekitar 14 km/jam. 🌬️
#
# Siang hari, jam 12:00, cuaca berubah menjadi hujan lebat dengan suhu naik menjadi 30°C dan keseimbangan angin yang kencang di barat daya sekitar 22 km/jam. Hujan sangat padat dengan persentase kabut 100%. 🌧️🌬️
#
# Pukul 18:00 WIB, cuaca mulai semakin stabil dan mulai kembali cerah dengan suhu turun sedikit menjadi 27°C. Angin lebih santai di barat laut dengan kencangan sekitar 15 km/jam. Cuaca di kategori berawan dan keseimbangan angin masih diperhatikan. ☁️🌬️
#
# Ini prakiraan BMKG, dengan akurasi sekitar 80%. Kabar baik, hujan tidak terlalu lama dan suhu masih dalam kategori yang nyaman. 🌞☀️
#
# Catatan: Ini prakiraan meteorologi, mungkin ada perubahan. Sempat diingatkan ya! 😊🌤️
# ✅ Semua data sudah masuk ke Google Spreadsheet: https://docs.google.com/spreadsheets/d/1MUDyBDen9l-yKgU7qN8GO2uNqlx0PiKbBxKNfrITQQU
# ## 🌈 Kesimpulan Umum 3 Hari ke Depan
# ---
# ### 🌟 Ringkasan Umum
#
# Selamat datang di Karawang, selamat menikmati hari-hari yang ada! Berikut adalah kesimpulan umum cuaca BMKG untuk hari Senin (21 September 2025), hari Rabu (23 September 2025), dan hari Jumat (25 September 2025):
#
# **Hari Senin (21 September 2025):**
# - Pagi: Cerah dengan suhu 26°C, kelembaban 80%, angin 14 km/jam (Tenggara), kemungkinan hujan 20%.
# - Siang: Hujan dengan suhu 30°C, kelembaban 65%, angin 22 km/jam (Barat Daya), kemungkinan hujan 100%.
# - Malam: Berawan dengan suhu 27°C, kelembaban 75%, angin 15 km/jam (Barat Laut), kemungkinan hujan 60%.
#
# **Hari Rabu (23 September 2025):**
# - Pagi: Cerah dengan suhu 26°C, kelembaban 70%, angin 14 km/jam (Selatan), kemungkinan hujan 30%.
# - Siang: Hujan lebat dengan suhu 28°C, kelembaban 70%, angin 22 km/jam (Barat Laut), kemungkinan hujan 100%.
# - Malam: Berawan dengan suhu 27°C, kelembaban 75%, angin 15 km/jam (Barat Laut), kemungkinan hujan 60%.
#
# **Hari Jumat (25 September 2025):**
# - Pagi: Cerah dengan suhu 26°C, kelembaban 70%, angin 14 km/jam (Selatan), kemungkinan hujan 30%.
# - Siang: Huj
